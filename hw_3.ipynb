# %% [markdown]
# Прошу дать еще немного времени на выполнение задания, т.к. задания очень сложные, приходится искать и читать множество дополнительных материалов, чтобы хоть немного разобраться.

# %% [markdown]
# ## Теоретическая часть

# %% [markdown]
# 1. Вспомним прошлый вебинар, мы рассматривали User-User рекомендации и Item-Item рекомендации. Чем они отличаются и чем они похожи? Если есть функция item_item_rec(interaction_matrix). Можно ли использовать эту функцию для user_user_rec?
# В чем принципиальные отличия item-item рекомендаций от ALS?

# %% [markdown]
# **User-User** - сходство между пользователями, на основе рейтингов, которые эти пользователи дают.
#
# **Item-Item** - рекомендация похожих товаров, на основе тех, которые пользователь уже оценил. Товары похожи, если они получают одинаковые оценки у одних и тех же пользователей.
#
# Оба подхода имеют следующие слабые места: холодный старт - низкое качество предсказаний для новых или нетипичных пользователей или товаров, большая сложность, а значит низкая скорость работы.
#
# Оба подхода основаны на заполнении пропусков в матрице пользователи-товары, различие в том, как применять методы заполнения пропусков - в исходной или транспонированной матрице. Соответсвенно функцию item_item_rec можно использовать для user_user_rec.
#
# **Alternating Least Squares** позволяет обнаружить скрытые признаки товаров или интересы пользователей, обладает высокой скоростью работы,

# %% [markdown]
# 2. Приведите 3 примера весов (те, которых не было на вебинаре: сумма покупок, количество покупок - неинтересно) user-item матрицы для задачи рекомендаций товаров

# %% [markdown]
# - Время, проведенное пользователем на странице товара (количество кликов на странице товара - изучил ли характеристики/отзывы/фотографии);
# - Количество покупок конкретного товара относительно покупок товаров в данной категории;

# %% [markdown]
# 3. Какие ограничения есть у ALS? (Тип информации, линейность/нелинейность факторов и т д)

# %% [markdown]
# 4. Мы рассматривали bm_25_weight.
# Опишите, как он работает. Как сделать рекомендации только на основе bm_25? (Можно и нужно пользоваться любыми источниками, приложите на них ссылки). Какие еще способы перевзвешивания user-item матрицы Вы знаете / можете предложить (ещё 2-3 способа)?

# %% [markdown]
# ## Практическая часть

# %%
import implicit

# %%
# import data
# utils functions like in webinar

# %% [markdown]
# ### Подбор матрицы $c_{ui}$
# Попробуйте различные варианты матрицы весов (3+ вариантов). Обучите алгоритм для различных $C$. В качестве результата приведите таблицу: матрица весов - результат на train и validation.
# Сделате качественные выводы.

# %% [markdown]
# ### Оптимизация гипперпараметров
# Для лучшей матрицы весов из первого задания подберите оптимальные $\lambda$ и n_factors. Подбор можно делать вручную (цикл в цикле, аналог sklearn.GridSearch, или случайно - sklearn.RandomSearch). Или Вы можете воспользоваться библиотеками для автоматического подбора гипперпараметров (любые на Ваш вкус). В качестве результата постройте графики:
# 1. Значение параметра - время обучения
# 2. Значение параметра - качество train, качество validation
#
# Сделайте качественные выводы

# %%
for factor in [50, 100, 300]:
    model = ALS(factor, ...)

# %% [markdown]
# **P.S.** Не пишите отписки в качестве выводов. Мне интресены Ваши рассуждения, трудности, с которыми Вы столкнулись и что-то, что Вас удивило. Если выводы контринтуитивны - напишите об этом, в этом нет ничего страшного!
